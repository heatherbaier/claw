# %%
import numpy as np 
import cv2 
import matplotlib.pyplot as plt
import PIL.Image as Image
import rasterio as rio
import gym
import random

from gym import Env, spaces
import time

import matplotlib.patches as patches

from model import *

from torchvision import models, transforms

from earth_env import *

from IPython import display

font = cv2.FONT_HERSHEY_COMPLEX_SMALL 

torch.autograd.set_detect_anomaly(True)

# %%
env = EarthObs(num_channels = 3, num_actions = 5)
obs = env.reset()

# last_screen = env.get_screen()
current_screen = env.get_screen()

memory = ReplayMemory(10000)

# while True:

done = False

while not done:

    # Select and perform an action
    action = env.select_action()

    # Save current state so we can push it to memory in a couple lines
    current_state = env.view_box.clip_image(cv2.imread("./test_image.png"))

    _, reward, done, _ = env.step(action.item())

    next_state = env.view_box.clip_image(cv2.imread("./test_image.png"))

    memory.push(current_state, action, next_state, reward)

    print(action)

    env.render()

    # Perform one step of the optimization (on the policy network)
    env.optimize_model()


env.close()
# Out:
# /Users/heatherbaier/opt/anaconda3/envs/dhsrl/lib/python3.8/site-packages/gym/spaces/box.py:73: UserWarning: WARN: Box bound precision lowered by casting to float16
#   logger.warn(
# Random action!
# Migration Loss:  420.4695129394531
# Select!
# moved:  620 476
# Migration Loss:  420.4695129394531
# t1 pred:  tensor([[-0.4695]], grad_fn=<AddmmBackward>)   |  t2 pred:  tensor([[-0.4695]], grad_fn=<AddmmBackward>)   |  reward:  0
# tensor([[4]])
# Optimizing model!
# Random action!
# Migration Loss:  420.4695129394531
# moved:  620 508
# Migration Loss:  420.3634338378906
# t1 pred:  tensor([[-0.4695]], grad_fn=<AddmmBackward>)   |  t2 pred:  tensor([[-0.3634]], grad_fn=<AddmmBackward>)   |  reward:  10
# tensor([[1]])
# Optimizing model!
# Random action!
# Migration Loss:  420.3634338378906
# moved:  652 508
# Migration Loss:  420.1523742675781
# t1 pred:  tensor([[-0.3634]], grad_fn=<AddmmBackward>)   |  t2 pred:  tensor([[-0.1524]], grad_fn=<AddmmBackward>)   |  reward:  10
# tensor([[2]])
# Optimizing model!
# Random action!
# Migration Loss:  414.4007568359375
# Select!
# moved:  652 508
# Migration Loss:  414.4007568359375
# t1 pred:  tensor([[5.5992]], grad_fn=<AddmmBackward>)   |  t2 pred:  tensor([[5.5992]], grad_fn=<AddmmBackward>)   |  reward:  0
# tensor([[4]])
# Optimizing model!
# Random action!
# Migration Loss:  414.4007568359375
# moved:  652 540
# Migration Loss:  414.4137268066406
# t1 pred:  tensor([[5.5992]], grad_fn=<AddmmBackward>)   |  t2 pred:  tensor([[5.5863]], grad_fn=<AddmmBackward>)   |  reward:  0
# tensor([[1]])
# Optimizing model!
# Random action!
# Migration Loss:  414.4137268066406
# moved:  684 540
# Migration Loss:  414.411865234375
# t1 pred:  tensor([[5.5863]], grad_fn=<AddmmBackward>)   |  t2 pred:  tensor([[5.5881]], grad_fn=<AddmmBackward>)   |  reward:  10
# tensor([[2]])
# Optimizing model!
# Random action!
# Migration Loss:  414.411865234375
# moved:  652 540
# Migration Loss:  414.4137268066406
# t1 pred:  tensor([[5.5881]], grad_fn=<AddmmBackward>)   |  t2 pred:  tensor([[5.5863]], grad_fn=<AddmmBackward>)   |  reward:  0
# tensor([[3]])
# Optimizing model!
# Random action!
# Migration Loss:  406.1859130859375
# Select!
# moved:  652 540
# Migration Loss:  406.1859130859375
# t1 pred:  tensor([[13.8141]], grad_fn=<AddmmBackward>)   |  t2 pred:  tensor([[13.8141]], grad_fn=<AddmmBackward>)   |  reward:  0
# tensor([[4]])
# Optimizing model!
# Random action!
# Migration Loss:  406.1859130859375
# moved:  684 540
# Migration Loss:  406.1788024902344
# t1 pred:  tensor([[13.8141]], grad_fn=<AddmmBackward>)   |  t2 pred:  tensor([[13.8212]], grad_fn=<AddmmBackward>)   |  reward:  10
# tensor([[2]])
# Optimizing model!
# Random action!
# Migration Loss:  406.1788024902344
# moved:  716 540
# Migration Loss:  406.1960144042969
# t1 pred:  tensor([[13.8212]], grad_fn=<AddmmBackward>)   |  t2 pred:  tensor([[13.8040]], grad_fn=<AddmmBackward>)   |  reward:  0
# tensor([[2]])
# Optimizing model!
# Random action!
# Migration Loss:  406.1960144042969
# moved:  684 540
# Migration Loss:  406.1788024902344
# t1 pred:  tensor([[13.8040]], grad_fn=<AddmmBackward>)   |  t2 pred:  tensor([[13.8212]], grad_fn=<AddmmBackward>)   |  reward:  10
# tensor([[3]])
# Optimizing model!
# Random action!
# Migration Loss:  406.1788024902344
# moved:  652 540
# Migration Loss:  406.1859130859375
# t1 pred:  tensor([[13.8212]], grad_fn=<AddmmBackward>)   |  t2 pred:  tensor([[13.8141]], grad_fn=<AddmmBackward>)   |  reward:  0
# tensor([[3]])
# Optimizing model!
# Random action!
# Migration Loss:  406.1859130859375
# moved:  684 540
# Migration Loss:  406.1788024902344
# t1 pred:  tensor([[13.8141]], grad_fn=<AddmmBackward>)   |  t2 pred:  tensor([[13.8212]], grad_fn=<AddmmBackward>)   |  reward:  10
# tensor([[2]])
# Optimizing model!
# Random action!
# Migration Loss:  406.1788024902344
# moved:  652 540
# Migration Loss:  406.1859130859375
# t1 pred:  tensor([[13.8212]], grad_fn=<AddmmBackward>)   |  t2 pred:  tensor([[13.8141]], grad_fn=<AddmmBackward>)   |  reward:  0
# tensor([[3]])
# Optimizing model!
# Random action!
# Migration Loss:  406.1859130859375
# moved:  652 572
# Migration Loss:  406.203125
# t1 pred:  tensor([[13.8141]], grad_fn=<AddmmBackward>)   |  t2 pred:  tensor([[13.7969]], grad_fn=<AddmmBackward>)   |  reward:  0
# tensor([[1]])
# Optimizing model!
# Random action!
# Migration Loss:  406.203125
# moved:  684 572
# Migration Loss:  406.2201843261719
# t1 pred:  tensor([[13.7969]], grad_fn=<AddmmBackward>)   |  t2 pred:  tensor([[13.7798]], grad_fn=<AddmmBackward>)   |  reward:  0
# tensor([[2]])
# Optimizing model!
# Random action!
# Migration Loss:  406.2201843261719
# moved:  684 604
# Migration Loss:  406.1574401855469
# t1 pred:  tensor([[13.7798]], grad_fn=<AddmmBackward>)   |  t2 pred:  tensor([[13.8425]], grad_fn=<AddmmBackward>)   |  reward:  10
# tensor([[1]])
# Optimizing model!
# Random action!
# Migration Loss:  406.1574401855469
# moved:  716 604
# Migration Loss:  406.17333984375
# t1 pred:  tensor([[13.8425]], grad_fn=<AddmmBackward>)   |  t2 pred:  tensor([[13.8266]], grad_fn=<AddmmBackward>)   |  reward:  0
# tensor([[2]])
# Optimizing model!
# Random action!
# Migration Loss:  406.17333984375
# moved:  684 604
# Migration Loss:  406.1574401855469
# t1 pred:  tensor([[13.8266]], grad_fn=<AddmmBackward>)   |  t2 pred:  tensor([[13.8425]], grad_fn=<AddmmBackward>)   |  reward:  10
# tensor([[3]])
# Optimizing model!
# Random action!
# Migration Loss:  406.1574401855469
# moved:  684 636
# Migration Loss:  406.1784362792969
# t1 pred:  tensor([[13.8425]], grad_fn=<AddmmBackward>)   |  t2 pred:  tensor([[13.8216]], grad_fn=<AddmmBackward>)   |  reward:  0
# tensor([[1]])
# Optimizing model!
# Random action!
# Migration Loss:  399.7000427246094
# Select!
# moved:  684 636
# Migration Loss:  399.7000427246094
# t1 pred:  tensor([[20.2999]], grad_fn=<AddmmBackward>)   |  t2 pred:  tensor([[20.2999]], grad_fn=<AddmmBackward>)   |  reward:  0
# tensor([[4]])
# Optimizing model!
# Random action!
# Migration Loss:  399.7000427246094
# moved:  716 636
# Migration Loss:  399.6951599121094
# t1 pred:  tensor([[20.2999]], grad_fn=<AddmmBackward>)   |  t2 pred:  tensor([[20.3048]], grad_fn=<AddmmBackward>)   |  reward:  10
# tensor([[2]])
# Optimizing model!
# Random action!
# tensor([[4]])
# Optimizing model!
